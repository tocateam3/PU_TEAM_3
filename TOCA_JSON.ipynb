# %%
import snowflake.connector
import pandas as pd

connect = snowflake.connector.connect(
    account = 'pia10938.us-east-1',
    user = 'pu_team_3',
    password = '8a0268daeb2d8081',
    database = 'pu_team_3',
    schema = 'pu_team_3',
    warehouse = 'PU_S',
    role='pu_team_3',
)

# %%
sql_query = pd.read_sql_query('SELECT TRAINER_NAME, TRAINER_ID, CATEGORIES '
                              'FROM TRAINING WHERE CATEGORIES IS NOT NULL'
                              'AND TRAINER_NAME IS NOT NULL LIMIT 50', connect)
table = pd.DataFrame(sql_query)
connect.close()

# %%
table
# Out:
#          TRAINER_NAME  TRAINER_ID  \
# 0          Sam Horton        3972
# 1         Jacob Sayer        1589
# 2       Asa Eggleston        7277
# 3        Moyo Akinade        6281
# 4        Leonard Sims        3497
# 5       Bryhan Alonzo        1989
# 6           Tony Zito         142
# 7       Sam Nicholson          64
# 8     Quinn Heinbaugh        2379
# 9      Brandon Miller        4276
# 10          Tony Zito         142
# 11       Eric Carrion        6060
# 12       Miguel Cucue        4228
# 13       Alex Collier        3557
# 14    Laura  Rayfield        2011
# 15      Asa Eggleston        7277
# 16          Tara Gray        2242
# 17   Patrick Houseman        4075
# 18      Sam Nicholson          64
# 19      Bryhan Alonzo        1989
# 20       Jonny Mecado        1987
# 21    Douglas Salgado         916
# 22        Jacob Sayer        1589
# 23      William Coyer        3057
# 24  Luciano Trasolini        7300
# 25       Miguel Cucue        4228
# ...

# %%
table['CATEGORIES'].iloc[0]
# Out:
# '[\n  {\n    "_id": 39,\n    "categoryId": "626c44f1ef0aa6cfa3dab0c7",\n    "endTime": 1651262487576,\n    "exercises": [\n      {\n        "_id": 1103,\n        "adjusted": true,\n        "blueScoreBoard": {\n          "goals": 10,\n          "randomGoals": 0,\n          "team": "BLUE"\n        },\n        "connectedTargetsSerialNumber": [\n          "TTarget ID:001403",\n          "TTarget ID:001406",\n          "TTarget ID:001461",\n          "TTarget ID:001429"\n        ],\n        "deliveryCodes": [\n          {\n            "_id": -1,\n            "angle": "CENTER",\n            "ballCount": 1,\n            "deliveryCodeBallStatus": [\n              {\n                "ballNumber": 1,\n                "elevation": 0,\n                "scoreBoard": {\n                  "goals": 0,\n                  "randomGoals": 0,\n                  "team": "BLUE"\n                },\n                "scoredDurationAfterTargetLit": 0,\n                "scoredTimeStamp": 0,\n                "s
# ...

# %%
json_parse = pd.read_json(table['CATEGORIES'].iloc[25])

# %%
json_parse.head()
# Out:
#    _id                categoryId        endTime  \
# 0   -1  5ce72dd5ef0a14645a258198  1558654406885
#
#                                            exercises  exercisesCompleted  \
# 0  [{'_id': -1, 'adjusted': False, 'connectedTarg...                   7
#
#    exercisesStarted             name      startTime  totalBallsFired
# 0                 3  Custom Category  1558652602613              130

# %%
json_parse['exercises'].iloc[0]
# Out:
# [{'_id': -1,
#   'adjusted': False,
#   'connectedTargetsSerialNumber': ['TTarget ID:000111',
#    'TTarget ID:000125',
#    'TTarget ID:000127',
#    'TTarget ID:000128'],
#   'deliveryCodes': [{'_id': -1,
#     'angle': 'CENTER',
#     'ballCount': 18,
#     'deliveryCodeBallStatus': [{'ballNumber': 1,
#       'elevation': 24,
#       'scoreBoard': {'goals': 1, 'team': 'RED'},
#       'scoredDurationAfterTargetLit': 400,
#       'scoredTargetSerialNumber': ' TTarget ID:000111',
#       'scoredTimeStamp': 1558652680841,
#       'speed': 28,
#       'targets': [{'litType': 'FULL',
#         'serialNumber': 'TTarget ID:000111',
#         'team': 'RED'},
#        {'litType': 'FULL', 'serialNumber': 'TTarget ID:000125', 'team': 'RED'},
#        {'litType': 'FULL', 'serialNumber': 'TTarget ID:000127', 'team': 'RED'},
#        {'litType': 'FULL',
#         'serialNumber': 'TTarget ID:000128',
#         'team': 'RED'}],
#       'timeStamp': 1558652614559,
# ...

# %%
exercises_table = pd.json_normalize(json_parse['exercises'].iloc[0])

# %%
exercises_table
# Out:
#    _id  adjusted                       connectedTargetsSerialNumber  \
# 0   -1     False  [TTarget ID:000111, TTarget ID:000125, TTarget...
# 1   -1     False  [TTarget ID:000111, TTarget ID:000125, TTarget...
# 2   -1     False  [TTarget ID:000111, TTarget ID:000125, TTarget...
# 3   -1     False  [TTarget ID:000111, TTarget ID:000125, TTarget...
# 4   -1     False  [TTarget ID:000111, TTarget ID:000125, TTarget...
# 5   -1     False  [TTarget ID:000111, TTarget ID:000125, TTarget...
# 6   -1     False  [TTarget ID:000111, TTarget ID:000125, TTarget...
# 7   -1     False  [TTarget ID:000111, TTarget ID:000125, TTarget...
# 8   -1     False  [TTarget ID:000111, TTarget ID:000125, TTarget...
# 9   -1     False  [TTarget ID:000111, TTarget ID:000125, TTarget...
#
#                                        deliveryCodes        endTime  \
# 0  [{'_id': -1, 'angle': 'CENTER', 'ballCount': 1...  1558652723297
# 1  [{'_id': -1, 'angle': 'LEFT/RIGHT', 'ballCount...  1558652854120
# ...

# %%
delivery_table = pd.json_normalize(exercises_table['deliveryCodes'].iloc[0])

# %%
delivery_table
# Out:
#    _id   angle  ballCount                             deliveryCodeBallStatus  \
# 0   -1  CENTER         18  [{'ballNumber': 1, 'elevation': 24, 'scoreBoar...
#
#              deliveryCodeId    elevation        name  repeatCount speed  \
# 0  5ce72dd5ef0a14645a258140  FOOT_GROUND  18_G_C_2_6            1   TWO
#
#    timeInterval
# 0             6

# %%
delivery_status = pd.json_normalize(delivery_table['deliveryCodeBallStatus'])

# %%
delivery_status
# Out:
#                                                   0   \
# 0  {'ballNumber': 1, 'elevation': 24, 'scoredDura...
#
#                                                   1   \
# 0  {'ballNumber': 2, 'elevation': 0, 'scoredDurat...
#
#                                                   2   \
# 0  {'ballNumber': 3, 'elevation': 0, 'scoredDurat...
#
#                                                   3   \
# 0  {'ballNumber': 4, 'elevation': 0, 'scoredDurat...
#
#                                                   4   \
# 0  {'ballNumber': 5, 'elevation': 0, 'scoredDurat...
#
#                                                   5   \
# 0  {'ballNumber': 6, 'elevation': 0, 'scoredDurat...
#
#                                                   6   \
# 0  {'ballNumber': 7, 'elevation': 0, 'scoredDurat...
#
#                                                   7   \
# 0  {'ballNumber': 8, 'elevation': 0, 'scoredDurat...
#
#                                                   8   \
# ...

# %%
delivery_ball = pd.json_normalize(delivery_status[0].iloc[0])

# %%
delivery_ball
# Out:
#    ballNumber  elevation  scoredDurationAfterTargetLit  \
# 0           1         24                           400
#
#   scoredTargetSerialNumber  scoredTimeStamp  speed  \
# 0        TTarget ID:000111    1558652680841     28
#
#                                              targets      timeStamp  \
# 0  [{'litType': 'FULL', 'serialNumber': 'TTarget ...  1558652614559
#
#   touchTrainerSerialNumber  scoreBoard.goals scoreBoard.team
# 0        TOCA T2 ID:000552                 1             RED

# %%
import json
read_json = json.loads(table['CATEGORIES'].iloc[0])

# %%
read_json
# Out:
# [{'_id': -1,
#   'categoryId': '5ce7167bef0a14645a2572ce',
#   'endTime': 1558648372201,
#   'exercises': [{'_id': -1,
#     'adjusted': False,
#     'connectedTargetsSerialNumber': ['TTarget ID:000113',
#      'TTarget ID:000114',
#      'TTarget ID:000126',
#      'TTarget ID:000119'],
#     'deliveryCodes': [{'_id': -1,
#       'angle': 'CENTER',
#       'ballCount': 1,
#       'deliveryCodeBallStatus': [{'ballNumber': 1,
#         'elevation': 0,
#         'scoreBoard': {'goals': 1, 'team': 'GREEN'},
#         'scoredDurationAfterTargetLit': 1500,
#         'scoredTargetSerialNumber': ' TTarget ID:000114',
#         'scoredTimeStamp': 1558645049247,
#         'speed': 19,
#         'targets': [{'litType': 'HALF',
#           'serialNumber': 'TTarget ID:000113',
#           'team': 'GREEN'},
#          {'litType': 'HALF',
#           'serialNumber': 'TTarget ID:000114',
#           'team': 'GREEN'},
#          {'litType': 'HALF',
#           'serialNumber': 'TTarget ID:000126',
# ...

# %%
from flatten_json import flatten

flat_json = flatten(read_json[0])

# %%
json_parse = pd.json_normalize(flat_json)
json_parse
# Out:
#    _id                categoryId        endTime  exercises_0__id  \
# 0   -1  5ce7167bef0a14645a2572ce  1558648372201               -1
#
#    exercises_0_adjusted exercises_0_connectedTargetsSerialNumber_0  \
# 0                 False                          TTarget ID:000113
#
#   exercises_0_connectedTargetsSerialNumber_1  \
# 0                          TTarget ID:000114
#
#   exercises_0_connectedTargetsSerialNumber_2  \
# 0                          TTarget ID:000126
#
#   exercises_0_connectedTargetsSerialNumber_3  exercises_0_deliveryCodes_0__id  \
# 0                          TTarget ID:000119                               -1
#
#    ... exercises_20_startTime  exercises_20_status  \
# 0  ...          1558648241029            COMPLETED
#
#    exercises_20_targetPatternRun  exercises_20_totalBallsFired  \
# 0      18_L_C_4_7_4T_4L_FULL_A_B                            18
#
#    exercises_20_touchTrainerSerialNumber exercisesCompleted  exercisesStarted  \
# ...

# %%
json_parse
# Out:
#    _id                categoryId        endTime  \
# 0   39  626c44f1ef0aa6cfa3dab0c7  1651262487576
# 1   52  626c44f1ef0aa6cfa3dab0c8              0
# 2   41  626c44f1ef0aa6cfa3dab0c9              0
#
#                                            exercises  exercisesCompleted  \
# 0  [{'_id': 1103, 'adjusted': True, 'blueScoreBoa...                   4
# 1                                                 []                   0
# 2                                                 []                   0
#
#    exercisesRunWithTarget  exercisesStarted           name      startTime  \
# 0                       5                 1     ACTIVATION  1651261135488
# 1                       0                 0  FREE KICK OFF  1651261135488
# 2                       0                 0     CHALLENGES  1651261135488
#
#     structure  totalBallsFired
# 0  ACTIVATION               98
# 1    KICK_OFF                0
# 2  CHALLENGES                0

# %%
from snowflake.sqlalchemy import URL
from sqlalchemy import create_engine
from snowflake.connector.pandas_tools import pd_writer

engine = create_engine(URL(
    account = 'pia10938.us-east-1',
    user = 'pu_team_3',
    password = '8a0268daeb2d8081',
    database = 'pu_team_3',
    schema = 'pu_team_3',
    warehouse = 'PU_S',
    role='pu_team_3',
))

# %%
json_parse.columns = map(str.upper, json_parse.columns)
json_parse.to_sql('test', engine, index=False, method=pd_writer)
engine.dispose()
